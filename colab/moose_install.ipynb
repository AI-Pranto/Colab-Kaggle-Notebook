# %% [markdown]
# ## Install MOOSE

# %%
! pip install condacolab
import condacolab
condacolab.install_miniconda()
! conda config --add channels conda-forge
! conda install mamba -y
! mamba init
! conda config --add channels https://conda.software.inl.gov/public
! mamba install moose-tools moose-libmesh -y
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:26
# 🔁 Restarting kernel...
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
# ...

# %% [markdown]
# ## Cloning MOOSE Github repository and run Test

# %%
! mkdir projects
% cd /content/projects
! git clone https://github.com/idaholab/moose.git

import os
os.environ['LIBMESH_DIR'] = '/usr/local/libmesh'
os.environ['MOOSE_DIR'] = '/content/projects/moose'

% cd /content/projects/moose/test
! make -j 2
! ./run_tests -j 2
# Out:
# Streaming output truncated to the last 5000 lines.
# bcs/misc_bcs.vector_neumann_test .......................................................................... OK
# bcs/coupled_var_neumann.nonlinear/exo ..................................................................... OK
# outputs/console/multiapp.ts_end_multi_output .............................................................. OK
# ics/check_error.ics_on_same_block_both_global ............................................................. OK
# bcs/ad_penalty_dirichlet_bc.ad/function_penalty_dirichlet_bc_test ......................................... OK
# scaling/residual-based.jacobian-based/one-var ............................................................. OK
# scaling/resid-and-jac-together.scaling/jac_separate ....................................................... OK
# executioners/fixed_point.tagged_solution_vector/var ....................................................... OK
# ...

# %% [markdown]
# ## Create Application

# %%
% cd /content/projects/
! mkdir moose_practice
% cd /content/projects/moose_practice
! /content/projects/moose/scripts/stork.sh darcyThermoMech
# Out:
# /content/projects
# /content/projects/moose_practice
# Initialized empty Git repository in /content/projects/moose_practice/darcy_thermo_mech/.git/
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@95c1e2b95e24.(none)')
# MOOSE app created in '/content/projects/moose_practice/darcy_thermo_mech'
#
# To store your changes on github:
#     1. log in to your account
#     2. Create a new repository named darcy_thermo_mech
#     3. in this terminal run the following commands:
#          cd /content/projects/moose_practice/darcy_thermo_mech
#          git remote add origin https://github.com/YourGitHubUserName/darcy_thermo_mech
#          git commit -m "initial commit"
#          git push -u origin main
#
# ...

# %% [markdown]
# ## Compile and run Test

# %%
% cd /content/projects/moose_practice/darcy_thermo_mech/
! make -j 2
! ./run_tests -j4
# Out:
# /content/projects/moose_practice/darcy_thermo_mech
# Checking if header needs updating: /content/projects/moose/framework/include/base/MooseRevision.h...
# Rebuilding symlinks in /content/projects/moose/modules/module_loader/build/header_symlinks
# Rebuilding symlinks in /content/projects/moose_practice/darcy_thermo_mech/build/header_symlinks
# Compiling C++ with suffix (in opt mode) /content/projects/moose/modules/module_loader/src/ModulesApp.C...
# Compiling C++ (in opt mode) /content/projects/moose_practice/darcy_thermo_mech/src/base/darcyThermoMechApp.C...
# Compiling C++ (in opt mode) /content/projects/moose_practice/darcy_thermo_mech/src/main.C...
# Compiling C++ (in opt mode) /content/projects/moose_practice/darcy_thermo_mech/test/src/base/darcyThermoMechTestApp.C...
# Linking Library /content/projects/moose/modules/module_loader/lib/libmodule_loader_with-opt.la...
# Linking Library /content/projects/moose_practice/darcy_thermo_mech/lib/libdarcy_thermo_mech-opt.la...
# ...

# %% [markdown]
# ## Running the Problem

# %%
! mkdir problems
% cd /content/projects/moose_practice/darcy_thermo_mech/problems
! cp -r /content/projects/moose/examples/ex01_inputfile/ex01.i /content/projects/moose/examples/ex01_inputfile/mug.e .
! ../darcy_thermo_mech-opt -i ex01.i
# Out:
# /content/projects/moose_practice/darcy_thermo_mech/problems
# Framework Information:
# MOOSE Version:           git commit a8c2d0e4aa on 2022-07-11
# LibMesh Version:
# PETSc Version:           3.16.5
# SLEPc Version:           3.16.2
# Current Time:            Mon Jul 11 16:54:06 2022
# Executable Timestamp:    Mon Jul 11 16:53:57 2022
#
# Parallelism:
#   Num Processors:          1
#   Num Threads:             1
#
# Mesh:
#   Parallel Type:           replicated
#   Mesh Dimension:          3
#   Spatial Dimension:       3
#   Nodes:                   3774
#   Elems:                   2476
#   Num Subdomains:          1
#
# Nonlinear System:
#   Num DOFs:                3774
#   Num Local DOFs:          3774
#   Variables:               "diffused"
#   Finite Element Types:    "LAGRANGE"
#   Approximation Orders:    "FIRST"
#
# Execution Information:
#   Executioner:             Steady
#   Solver Mode:             Preconditioned JFNK
#
# LEGACY MODES ENABLED:
# ...
