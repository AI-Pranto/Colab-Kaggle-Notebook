# %% [markdown]
# ### [OpenFOAM Foundation](https://openfoam.org/)

# %%
# %%bash
# sh -c "wget -O - https://dl.openfoam.org/gpg.key | apt-key add -"
# add-apt-repository http://dl.openfoam.org/ubuntu
# apt-get update
# apt-get -y install openfoam9
# Out:
# --2021-09-28 05:52:17--  https://dl.openfoam.org/gpg.key
# Resolving dl.openfoam.org (dl.openfoam.org)... 35.179.33.128
# Connecting to dl.openfoam.org (dl.openfoam.org)|35.179.33.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1710 (1.7K) [application/pgp-keys]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.67K  --.-KB/s    in 0s
#
# 2021-09-28 05:52:18 (335 MB/s) - written to stdout [1710/1710]
#
# OK

# %%
# %%bash
#
# source /opt/openfoam9/etc/bashrc
#
# simpleFoam -help
# Out:
# Usage: simpleFoam [OPTIONS]
# options:
#   -case <dir>       specify alternate case directory, default is the cwd
#   -fileHandler <handler>
#                     override the fileHandler
#   -hostRoots <(((host1 dir1) .. (hostN dirN))>
#                     slave root directories (per host) for distributed running
#   -libs <(lib1 .. libN)>
#                     pre-load libraries
#   -listFunctionObjects
#                     List functionObjects
#   -listFvConstraints
#                     List fvConstraints
#   -listFvModels     List fvModels
#   -listMomentumTransportModels
#                     List momentumTransportModels
#   -listScalarBCs    List scalar field boundary conditions (fvPatchField<scalar>)
#   -listSwitches     List all available debug, info and optimisation switches
#   -listVectorBCs    List vector field boundary conditions (fvPatchField<vector>)
#   -noFunctionObjects
#                     do not execute functionObjects
#   -parallel         run in parallel
# ...

# %% [markdown]
# ### [ESI-OpenCFD](https://www.openfoam.com/)

# %%
# %%bash
# wget -q -O - https://dl.openfoam.com/add-debian-repo.sh | sudo bash
# apt-get install openfoam2106-default gnuplot -y
# Out:
# Detected distribution code-name: bionic
# Added /etc/apt/sources.list.d/openfoam.list
# Importing openfoam gpg key... done
# Overwrote /etc/apt/trusted.gpg.d/openfoam.gpg
# Running apt-get update... done
#
# The repository is setup! You can now install packages.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   flex libcgal-dev libcgal13 libfftw3-bin libfftw3-dev libfftw3-long3
#   libfftw3-quad3 libfftw3-single3 libfl-dev libfl2 libgmp-dev libgmpxx4ldbl
#   libmpfr-dev libptscotch-6.0 libptscotch-dev libscotch-6.0 libscotch-dev
#   libsigsegv2 m4 openfoam-selector openfoam2106 openfoam2106-common
#   openfoam2106-dev openfoam2106-source openfoam2106-tools
#   openfoam2106-tutorials
# Suggested packages:
#   bison flex-doc libmpfi-dev libntl-dev libfftw3-doc gmp-doc libgmp10-doc
#   libmpfr-doc m4-doc gnuplot
# The following NEW packages will be installed:
# ...

# %%
# %%bash
# source /usr/lib/openfoam/openfoam2106/etc/bashrc
#
# simpleFoam -help
# Out:
# Usage: simpleFoam [OPTIONS]
# Options:
#   -case <dir>       Specify case directory to use (instead of cwd)
#   -decomposeParDict <file>
#                     Use specified file for decomposePar dictionary
#   -dry-run          Check case set-up only using a single time step
#   -dry-run-write    Check case set-up and write only using a single time step
#   -parallel         Run in parallel
#   -postProcess      Execute functionObjects only
#   -doc              Display documentation in browser
#   -help             Display short help and exit
#   -help-full        Display full help and exit
#
# Steady-state solver for incompressible, turbulent flows.
#
# Using: OpenFOAM-2106 (2106) - visit www.openfoam.com
# Build: _7b82832f-20210625
# Arch:  LSB;label=32;scalar=64

# %%
% cd /content/
! git clone https://gitlab.com/foam-for-nuclear/GeN-Foam.git
% cd GeN-Foam/GeN-Foam
# Out:
# Cloning into 'GeN-Foam'...
# remote: Enumerating objects: 19607, done.
# remote: Counting objects: 100% (1470/1470), done.
# remote: Compressing objects: 100% (646/646), done.
# remote: Total 19607 (delta 816), reused 1426 (delta 796), pack-reused 18137
# Receiving objects: 100% (19607/19607), 252.16 MiB | 29.95 MiB/s, done.
# Resolving deltas: 100% (12195/12195), done.
# Checking out files: 100% (1982/1982), done.
# /content/GeN-Foam/GeN-Foam
# ./Allwclean: 4: ./Allwclean: wclean: not found
# ./Allwclean: 5: ./Allwclean: wclean: not found
# ./Allwclean: 6: ./Allwclean: wclean: not found
# ./Allwmake: 6: ./Allwmake: wmake: not found
# ./Allwmake: 7: ./Allwmake: wmake: not found
# ./Allwmake: 8: ./Allwmake: wmake: not found

# %%
# %%bash
# source /usr/lib/openfoam/openfoam2106/etc/bashrc
# ./Allwclean
# ./Allwmake
# Out:
# wclean libso classes/thermalHydraulics/src
# wclean libso classes/thermalHydraulics/solvers
# wmake libso ./classes/thermalHydraulics/src
# Making dependency list for source file patchScalarFieldValue.C
# Making dependency list for source file stopIfMaxFieldDiff.C
# Making dependency list for source file pressureDrop.C
# Making dependency list for source file massFlow.C
# Making dependency list for source file TBulk.C
# Making dependency list for source file fieldDiffExtents.C
# Making dependency list for source file timeFieldTableFvPatchScalarField.C
# Making dependency list for source file velocityRundownFvPatchVectorField.C
# Making dependency list for source file NusseltThermalBaffle1DFvPatchScalarField.C
# Making dependency list for source file customPimpleControl.C
# Making dependency list for source file byRegimeModels.C
# Making dependency list for source file constantModels.C
# Making dependency list for source file BrowningPotter.C
# ...

# %%
# %%bash
# source /usr/lib/openfoam/openfoam2106/etc/bashrc
#
# cd /content/GeN-Foam/Tutorials/3D_SmallESFR
# ./Allclean
# ./Allrun
# Out:
# Preparing to run case steadyState...
# Cloning rootCase to case steadyState...rootCase cloned!
# Steady state case is prepared!
# /usr/bin/gnuplot
# Running GeN-Foam on steadyState
# /*---------------------------------------------------------------------------*\
# | =========                 |                                                 |
# | \\      /  F ield         | OpenFOAM: The Open Source CFD Toolbox           |
# |  \\    /   O peration     | Version:  2106                                  |
# |   \\  /    A nd           | Website:  www.openfoam.com                      |
# |    \\/     M anipulation  |                                                 |
# \*---------------------------------------------------------------------------*/
# Build  : _7b82832f-20210625 OPENFOAM=2106
# Arch   : "LSB;label=32;scalar=64"
# Exec   : GeN-Foam -case steadyState
# Date   : Sep 28 2021
# Time   : 07:24:52
# Host   : f0843848b453
# PID    : 5046
# I/O    : uncollated
# ...

# %%
% cd /content/
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content
# Mounted at /content/drive

# %%
! cp -r /content/GeN-Foam/Tutorials/3D_SmallESFR/ /content/drive/MyDrive/gen-foam/
