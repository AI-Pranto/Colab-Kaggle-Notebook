# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
! conda install openmc=0.15.0=nodagmc_nompi_* -y
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openmc==0.15.0[build=nodagmc_nompi_*]
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-2.4.1            |     pyhd8ed1ab_0          28 KB  conda-forge
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
# ...

# %%
! wget -O - https://anl.box.com/shared/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz | tar -C /content/ -xJ
import os
os.environ['OPENMC_CROSS_SECTIONS'] = "/content/endfb-vii.1-hdf5/cross_sections.xml"
# Out:
# --2024-12-02 02:16:10--  https://anl.box.com/shared/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz
# Resolving anl.box.com (anl.box.com)... 74.112.186.157
# Connecting to anl.box.com (anl.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz [following]
# --2024-12-02 02:16:10--  https://anl.box.com/public/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz
# Reusing existing connection to anl.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://anl.app.box.com/public/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz [following]
# --2024-12-02 02:16:10--  https://anl.app.box.com/public/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz
# Resolving anl.app.box.com (anl.app.box.com)... 74.112.186.157
# Connecting to anl.app.box.com (anl.app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import openmc.lib
