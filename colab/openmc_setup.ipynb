# %%
! pip install condacolab
import condacolab
condacolab.install_miniconda()
# Out:
# ...
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:34
# 🔁 Restarting kernel...

# %%
# %%bash
# wget https://anl.box.com/shared/static/uhbxlrx7hvxqw27psymfbhi7bx7s6u6a.xz
# tar -xvf uhbxlrx7hvxqw27psymfbhi7bx7s6u6a.xz
# rm -f uhbxlrx7hvxqw27psymfbhi7bx7s6u6a.xz

# %%
! conda install openmc=0.12.2 -c conda-forge -y
import os
os.environ['OPENMC_CROSS_SECTIONS'] = "/content/endfb80_hdf5/cross_sections.xml"
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - openmc=0.12.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            1_gnu          22 KB
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     certifi-2021.5.30          |   py37h89c1867_0         141 KB  conda-forge
# ...

# %%
! conda list openmc
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# openmc                    0.12.2           py37hb0e9ad2_0    conda-forge
