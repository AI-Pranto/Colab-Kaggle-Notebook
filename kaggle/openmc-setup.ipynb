# %%
! conda install -c conda-forge mamba -y -q
! mamba install openmc -y
! wget -q -O - https://anl.box.com/shared/static/9igk353zpy8fn9ttvtrqgzvw1vtejoz6.xz | tar -C /kaggle/working/ -xJ
import os
os.environ['OPENMC_CROSS_SECTIONS'] = "/kaggle/working/endfb71_hdf5/cross_sections.xml"

# %%
import openmc.lib
